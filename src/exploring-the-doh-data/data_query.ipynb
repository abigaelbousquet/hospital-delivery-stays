# %% [markdown]
# # Querying Hospital Inpatient Discharges (SPARCS De-Identified) from Open Data NY - Department of Health
# See the NY Gov overview [here](https://health.data.ny.gov/Health/Hospital-Inpatient-Discharges-SPARCS-De-Identified/tg3i-cinn)

# %% [markdown]
# Using query help from [https://dev.socrata.com/foundry/health.data.ny.gov/tg3i-cinn](https://dev.socrata.com/foundry/health.data.ny.gov/tg3i-cinn)

# %% [markdown]
# ## All discharge data (skip this)

# %%
import numpy as np

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("health.data.ny.gov", None)
results = client.get("tg3i-cinn", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
results_df
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#      hospital_service_area hospital_county operating_certificate_number  \
# 0            New York City           Bronx                      7000006
# 1            New York City           Bronx                      7000006
# 2            New York City           Bronx                      7000006
# 3            New York City           Bronx                      7000006
# 4            New York City           Bronx                      7000006
# ...                    ...             ...                          ...
# 1995         New York City       Manhattan                      7002001
# 1996         New York City           Kings                      7001009
# 1997         New York City       Manhattan                      7002001
# 1998         Hudson Valley        Rockland                      4324000
# 1999         New York City       Manhattan                      7002001
#
#      permanent_facility_id                                      facility_name  \
# 0                   001169  Montefiore Medical Center - Henry & Lucy Moses...
# 1                   001169  Montefiore Medical Center - Henry & Lucy Moses...
# 2                   001168       Montefiore Medical Center-Wakefield Hospital
# 3                   003058  Montefiore Med Center - Jack D Weiler Hosp of ...
# 4                   001169  Montefiore Medical Center - Henry & Lucy Moses...
# ...                    ...                                                ...
# 1995                001438                           Bellevue Hospital Center
# 1996                001294                              Coney Island Hospital
# 1997                001438                           Bellevue Hospital Center
# 1998                000776                                   Montefiore Nyack
# 1999                001438                           Bellevue Hospital Center
#
#         age_group zip_code_3_digits gender                    race  \
# 0     70 or Older               104      M              Other Race
# 1        50 to 69               104      F                   White
# 2        18 to 29               104      F              Other Race
# 3     70 or Older               104      M              Other Race
# 4        50 to 69               104      F  Black/African American
# ...           ...               ...    ...                     ...
# 1995  70 or Older               112      M  Black/African American
# 1996     30 to 49               112      F                   White
# 1997      0 to 17               113      F              Other Race
# 1998  70 or Older               109      M                   White
# 1999     50 to 69               100      M              Other Race
#
#               ethnicity  ... apr_severity_of_illness apr_risk_of_mortality  \
# 0      Spanish/Hispanic  ...                   Major               Extreme
# 1     Not Span/Hispanic  ...                Moderate                 Minor
# 2      Spanish/Hispanic  ...                   Minor                 Minor
# 3      Spanish/Hispanic  ...                   Major                 Major
# 4     Not Span/Hispanic  ...                Moderate                 Minor
# ...                 ...  ...                     ...                   ...
# 1995  Not Span/Hispanic  ...                Moderate              Moderate
# 1996  Not Span/Hispanic  ...                   Minor                 Minor
# 1997   Spanish/Hispanic  ...                   Minor                 Minor
# 1998  Not Span/Hispanic  ...                 Extreme               Extreme
# 1999            Unknown  ...                   Major                 Major
#
#      apr_medical_surgical        payment_typology_1 payment_typology_2  \
# 0                 Medical                  Medicare           Medicaid
# 1                 Medical  Private Health Insurance                NaN
# 2                Surgical                  Medicaid                NaN
# 3                 Medical                  Medicare           Medicaid
# 4                 Medical                  Medicare           Medicaid
# ...                   ...                       ...                ...
# 1995             Surgical                  Medicaid                NaN
# 1996             Surgical                  Medicaid                NaN
# 1997              Medical                  Medicaid                NaN
# 1998              Medical                  Medicare                NaN
# 1999              Medical                  Medicare                NaN
#
#      emergency_department_indicator total_charges total_costs birth_weight  \
# 0                                 Y     320922.43    60241.34          NaN
# 1                                 Y      61665.22     9180.69          NaN
# 2                                 N      42705.34    11366.50          NaN
# 3                                 Y      72700.17    12111.75          NaN
# 4                                 Y      55562.51     8339.72          NaN
# ...                             ...           ...         ...          ...
# 1995                              N     157971.13    90846.67          NaN
# 1996                              N      39071.37    17854.80          NaN
# 1997                              N      14311.91     8230.55        02600
# 1998                              Y     135524.70    26028.38          NaN
# 1999                              Y     249538.74   143505.74          NaN
#
#      payment_typology_3
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 1995                NaN
# 1996                NaN
# 1997                NaN
# 1998                NaN
# 1999                NaN
#
# [2000 rows x 33 columns]

# %% [markdown]
# ## All columns in this data

# %%
results_df.columns
# Out:
# Index(['hospital_service_area', 'hospital_county',
#        'operating_certificate_number', 'permanent_facility_id',
#        'facility_name', 'age_group', 'zip_code_3_digits', 'gender', 'race',
#        'ethnicity', 'length_of_stay', 'type_of_admission',
#        'patient_disposition', 'discharge_year', 'ccsr_diagnosis_code',
#        'ccsr_diagnosis_description', 'ccsr_procedure_code',
#        'ccsr_procedure_description', 'apr_drg_code', 'apr_drg_description',
#        'apr_mdc_code', 'apr_mdc_description', 'apr_severity_of_illness_code',
#        'apr_severity_of_illness', 'apr_risk_of_mortality',
#        'apr_medical_surgical', 'payment_typology_1', 'payment_typology_2',
#        'emergency_department_indicator', 'total_charges', 'total_costs',
#        'birth_weight', 'payment_typology_3'],
#       dtype='object')

# %%
results_df['ccsr_diagnosis_description'].unique()
# Out:
# array(['CORONAVIRUS DISEASE 2019 (COVID-19)', 'MULTIPLE SCLEROSIS',
#        'PREVIOUS C-SECTION', 'URINARY TRACT INFECTIONS',
#        'PARALYSIS (OTHER THAN CEREBRAL PALSY)',
#        'COMPLICATION OF OTHER SURGICAL OR MEDICAL CARE, INJURY, INITIAL ENCOUNTER',
#        'TRAUMATIC BRAIN INJURY (TBI); CONCUSSION, INITIAL ENCOUNTER',
#        'LIVEBORN', 'NONINFECTIOUS GASTROENTERITIS', 'ASTHMA',
#        'DIABETES MELLITUS WITH COMPLICATION', 'SICKLE CELL TRAIT/ANEMIA',
#        'CHRONIC OBSTRUCTIVE PULMONARY DISEASE AND BRONCHIECTASIS',
#        'OTHER SPECIFIED DISEASES OF VEINS AND LYMPHATICS',
#        'STRESS FRACTURE, INITIAL ENCOUNTER',
#        'ENCOUNTER FOR ANTINEOPLASTIC THERAPIES', 'BENIGN NEOPLASMS',
#        'NERVE AND NERVE ROOT DISORDERS',
#        'COMPLICATION OF TRANSPLANTED ORGANS OR TISSUE, INITIAL ENCOUNTER',
#        'FLUID AND ELECTROLYTE DISORDERS',
#        'INTESTINAL OBSTRUCTION AND ILEUS', 'EPILEPSY; CONVULSIONS',
#        'MALE REPRODUCTIVE SYSTEM CANCERS - PROSTATE',
#        'SCHIZOPHRENIA SPECTRUM AND OTHER PSYCHOTIC DISORDERS',
#        'CORONARY ATHEROSCLEROSIS AND OTHER HEART DISEASE',
#        'ALCOHOL-RELATED DISORDERS',
#        'HYPERTENSION AND HYPERTENSIVE-RELATED CONDITIONS COMPLICATING PREGNANCY; CHILDBIRTH; AND THE PUERPERIUM',
#        'CEREBRAL INFARCTION',
#        'OTHER SPECIFIED AND UNSPECIFIED GASTROINTESTINAL DISORDERS',
#        'FRACTURE OF TORSO, INITIAL ENCOUNTER',
#        'COMPLICATIONS SPECIFIED DURING CHILDBIRTH', 'SEPTICEMIA',
#        'HEART FAILURE', 'GANGRENE', 'NEUROCOGNITIVE DISORDERS',
#        'ACUTE MYOCARDIAL INFARCTION', 'ACUTE PULMONARY EMBOLISM',
#        'HEADACHE; INCLUDING MIGRAINE', 'OBESITY',
#        'NERVOUS SYSTEM PAIN AND PAIN SYNDROMES', 'ASPIRATION PNEUMONITIS',
#        'SPONDYLOPATHIES/SPONDYLOARTHROPATHY (INCLUDING INFECTIVE)',
#        'DISLOCATIONS, INITIAL ENCOUNTER', 'MULTIPLE MYELOMA',
#        'BILIARY TRACT DISEASE', 'CHRONIC KIDNEY DISEASE',
#        'POISONING BY DRUGS, INITIAL ENCOUNTER', 'SECONDARY MALIGNANCIES',
#        'POSTPROCEDURAL OR POSTOPERATIVE DIGESTIVE SYSTEM COMPLICATION',
#        'DIVERTICULOSIS AND DIVERTICULITIS',
#        'MALPOSITION, DISPROPORTION OR OTHER LABOR COMPLICATIONS',
#        'APPENDICITIS AND OTHER APPENDICEAL CONDITIONS',
#        'DIABETES OR ABNORMAL GLUCOSE TOLERANCE COMPLICATING PREGNANCY; CHILDBIRTH; OR THE PUERPERIUM',
#        'OTHER SPECIFIED AND UNSPECIFIED MOOD DISORDERS',
#        'MATERNAL CARE RELATED TO FETAL CONDITIONS',
#        'OTHER SPECIFIED SUBSTANCE-RELATED DISORDERS',
#        'OPEN WOUNDS OF HEAD AND NECK, INITIAL ENCOUNTER',
#        'PNEUMONIA (EXCEPT THAT CAUSED BY TUBERCULOSIS)',
#        'CIRCULATORY SIGNS AND SYMPTOMS', 'NAUSEA AND VOMITING',
#        'MENINGITIS', 'PERITONITIS AND INTRA-ABDOMINAL ABSCESS',
#        'STIMULANT-RELATED DISORDERS', 'SYNCOPE', 'GASTRODUODENAL ULCER',
#        'FRACTURE OF THE UPPER LIMB, INITIAL ENCOUNTER',
#        'CARDIAC DYSRHYTHMIAS', 'OPEN WOUNDS TO LIMBS, INITIAL ENCOUNTER',
#        'ABDOMINAL HERNIA', 'TRANSIENT CEREBRAL ISCHEMIA',
#        'MOLAR PREGNANCY AND OTHER ABNORMAL PRODUCTS OF CONCEPTION',
#        'BENIGN OVARIAN CYST', 'GASTRITIS AND DUODENITIS',
#        'ALLERGIC REACTIONS', 'AMPUTATION OF A LIMB, INITIAL ENCOUNTER',
#        'ACUTE AND UNSPECIFIED RENAL FAILURE',
#        'SKIN AND SUBCUTANEOUS TISSUE INFECTIONS', 'DEPRESSIVE DISORDERS',
#        'RESPIRATORY FAILURE; INSUFFICIENCY; ARREST',
#        'BIPOLAR AND RELATED DISORDERS',
#        'TRAUMA- AND STRESSOR-RELATED DISORDERS',
#        'MATERNAL CARE RELATED TO DISORDERS OF THE PLACENTA AND PLACENTAL IMPLANTATION',
#        'NEURO-OPHTHALMOLOGY', 'HEMORRHOIDS', 'NONINFECTIOUS HEPATITIS',
#        'PROLONGED PREGNANCY',
#        'ECTOPIC PREGNANCY AND COMPLICATIONS OF ECTOPIC PREGNANCY',
#        'EARLY, FIRST OR UNSPECIFIED TRIMESTER HEMORRHAGE',
#        'OTHER AFTERCARE ENCOUNTER', 'ACUTE BRONCHITIS',
#        'PERINATAL INFECTIONS',
#        'POLYHYDRAMNIOS AND OTHER PROBLEMS OF AMNIOTIC CAVITY',
#        'MALAISE AND FATIGUE',
#        'SEQUELA OF HEMORRHAGIC CEREBROVASCULAR DISEASE',
#        'EARLY OR THREATENED LABOR', 'OSTEOARTHRITIS',
#        'UNCOMPLICATED PREGNANCY, DELIVERY OR PUERPERIUM',
#        'OCCLUSION OR STENOSIS OF PRECEREBRAL OR CEREBRAL ARTERIES WITHOUT INFARCTION',
#        'RESPIRATORY CANCERS', 'MULTIPLE GESTATION', 'PNEUMOTHORAX',
#        'IMMUNITY DISORDERS', 'OTHER SPECIFIED NERVOUS SYSTEM DISORDERS',
#        'PANCREATIC DISORDERS (EXCLUDING DIABETES)',
#        'ESOPHAGEAL DISORDERS',
#        'OTHER SPECIFIED AND UNSPECIFIED DISEASES OF KIDNEY AND URETERS',
#        'ABDOMINAL PAIN AND OTHER DIGESTIVE/ABDOMEN SIGNS AND SYMPTOMS',
#        'MYELODYSPLASTIC SYNDROME (MDS)',
#        'OTHER AND ILL-DEFINED CEREBROVASCULAR DISEASE',
#        'CARDIAC ARREST AND VENTRICULAR FIBRILLATION',
#        'SPONTANEOUS ABORTION AND COMPLICATIONS OF SPONTANEOUS ABORTION',
#        'GASTROINTESTINAL CANCERS - STOMACH',
#        'INFLAMMATORY CONDITIONS OF MALE GENITAL ORGANS',
#        'SLEEP WAKE DISORDERS',
#        'OTHER SPECIFIED AND UNSPECIFIED DISEASES OF BLADDER AND URETHRA',
#        'OTHER SPECIFIED AND UNSPECIFIED SKIN DISORDERS',
#        'PERIPHERAL AND VISCERAL VASCULAR DISEASE',
#        'ESSENTIAL HYPERTENSION', 'OSTEOMYELITIS',
#        'OTHER SPECIFIED COMPLICATIONS IN PREGNANCY',
#        'GASTROINTESTINAL HEMORRHAGE', 'PERSONALITY DISORDERS',
#        'INTERNAL ORGAN INJURY, INITIAL ENCOUNTER', 'MESOTHELIOMA',
#        'PERICARDITIS AND PERICARDIAL DISEASE',
#        'HYPERTENSION WITH COMPLICATIONS AND SECONDARY HYPERTENSION',
#        'FRACTURE OF THE NECK OF THE FEMUR (HIP), INITIAL ENCOUNTER',
#        'POSTTHROMBOTIC SYNDROME AND VENOUS INSUFFICIENCY/HYPERTENSION',
#        'SEQUELA OF CEREBRAL INFARCTION AND OTHER CEREBROVASCULAR DISEASE',
#        'ANXIETY AND FEAR-RELATED DISORDERS',
#        'LEUKEMIA - ACUTE MYELOID LEUKEMIA (AML)',
#        'URINARY SYSTEM CANCERS - BLADDER',
#        'GENERAL SENSATION/PERCEPTION SIGNS AND SYMPTOMS',
#        'ARTERIAL DISSECTIONS',
#        'FRACTURE OF THE LOWER LIMB (EXCEPT HIP), INITIAL ENCOUNTER',
#        'ACUTE PHLEBITIS; THROMBOPHLEBITIS AND THROMBOEMBOLISM',
#        'ABNORMAL FINDINGS WITHOUT DIAGNOSIS',
#        'TRAUMATIC BRAIN INJURY (TBI); CONCUSSION, SUBSEQUENT ENCOUNTER',
#        'COMPLICATION OF INTERNAL ORTHOPEDIC DEVICE OR IMPLANT, INITIAL ENCOUNTER',
#        'COMPLICATION OF GENITOURINARY DEVICE, IMPLANT OR GRAFT, INITIAL ENCOUNTER',
#        'HYPOTENSION', 'SUICIDAL IDEATION/ATTEMPT/INTENTIONAL SELF-HARM',
#        'DRUG INDUCED OR TOXIC RELATED CONDITION',
#        'OPIOID-RELATED DISORDERS',
#        'OTHER SPECIFIED AND UNSPECIFIED LIVER DISEASE',
#        'NONSPECIFIC CHEST PAIN', 'INFECTIVE ARTHRITIS', 'SARCOMA',
#        'OTHER SPECIFIED AND UNSPECIFIED PERINATAL CONDITIONS',
#        'CANNABIS-RELATED DISORDERS', 'NEURODEVELOPMENTAL DISORDERS',
#        'CHRONIC RHEUMATIC HEART DISEASE', 'HEPATITIS',
#        'HEMOLYTIC JAUNDICE AND PERINATAL JAUNDICE', 'MUSCLE DISORDERS',
#        'DYSPHAGIA', 'CONDUCTION DISORDERS',
#        'TOXIC EFFECTS, INITIAL ENCOUNTER', 'PITUITARY DISORDERS',
#        'AORTIC; PERIPHERAL; AND VISCERAL ARTERY ANEURYSMS',
#        'INTESTINAL INFECTION',
#        'EFFECT OF FOREIGN BODY ENTERING OPENING, INITIAL ENCOUNTER',
#        'BREAST CANCER - ALL OTHER TYPES',
#        'INFLAMMATORY DISEASES OF FEMALE PELVIC ORGANS',
#        'FRACTURE OF HEAD AND NECK, INITIAL ENCOUNTER',
#        'ERECTILE DYSFUNCTION',
#        'SUPERFICIAL INJURY; CONTUSION, INITIAL ENCOUNTER',
#        'POSTPROCEDURAL OR POSTOPERATIVE RESPIRATORY SYSTEM COMPLICATION',
#        'TENDON AND SYNOVIAL DISORDERS',
#        'SYSTEMIC LUPUS ERYTHEMATOSUS AND CONNECTIVE TISSUE DISORDERS',
#        'NERVOUS SYSTEM CONGENITAL ANOMALIES',
#        'AORTIC AND PERIPHERAL ARTERIAL EMBOLISM OR THROMBOSIS',
#        'HYPERPLASIA OF PROSTATE', 'OTHER UNSPECIFIED INJURY',
#        'NEPHRITIS; NEPHROSIS; RENAL SCLEROSIS',
#        'OTHER SPECIFIED UPPER RESPIRATORY INFECTIONS',
#        'NEOPLASM-RELATED ENCOUNTERS', 'CALCULUS OF URINARY TRACT',
#        'GENITOURINARY CONGENITAL ANOMALIES',
#        'NONMALIGNANT BREAST CONDITIONS',
#        'OTHER SPECIFIED AND UNSPECIFIED LOWER RESPIRATORY DISEASE',
#        'MUSCULOSKELETAL PAIN, NOT LOW BACK PAIN',
#        'NERVOUS SYSTEM SIGNS AND SYMPTOMS',
#        'ACUTE AND CHRONIC TONSILLITIS',
#        'OTHER GENERAL SIGNS AND SYMPTOMS',
#        'OTHER SPECIFIED HEREDITARY AND DEGENERATIVE NERVOUS SYSTEM CONDITIONS',
#        'ANAL AND RECTAL CONDITIONS', 'POLYNEUROPATHIES',
#        'RESPIRATORY SIGNS AND SYMPTOMS',
#        'COAGULATION AND HEMORRHAGIC DISORDERS',
#        'DISEASES OF INNER EAR AND RELATED CONDITIONS', 'HEPATIC FAILURE',
#        'NON-PRESSURE ULCER OF SKIN',
#        'GASTROINTESTINAL CANCERS - COLORECTAL',
#        'COMPLICATIONS SPECIFIED DURING THE PUERPERIUM',
#        'CLEFT LIP OR PALATE', 'ACQUIRED DEFORMITIES (EXCLUDING FOOT)',
#        'ACUTE HEMORRHAGIC CEREBROVASCULAR DISEASE',
#        'OTHER SPECIFIED INFLAMMATORY CONDITION OF SKIN',
#        'MUSCULOSKELETAL CONGENITAL CONDITIONS', 'INJURY, SEQUELA',
#        'NONRHEUMATIC AND UNSPECIFIED VALVE DISORDERS',
#        'SCOLIOSIS AND OTHER POSTURAL DORSOPATHIC DEFORMITIES',
#        'OTHER SPECIFIED AND UNSPECIFIED UPPER RESPIRATORY DISEASE',
#        'PARKINSON`S DISEASE', 'DISORDERS OF JAW',
#        'OB-RELATED TRAUMA TO PERINEUM AND VULVA',
#        'COMA; STUPOR; AND BRAIN DAMAGE',
#        'MATERNAL CARE FOR ABNORMALITY OF PELVIC ORGANS',
#        'ACUTE POSTHEMORRHAGIC ANEMIA', 'MALNUTRITION',
#        'OPEN WOUNDS OF TRUNK, INITIAL ENCOUNTER',
#        'FRACTURE OF LOWER LIMB (EXCEPT HIP), SUBSEQUENT ENCOUNTER',
#        'FRACTURE OF TORSO, SUBSEQUENT ENCOUNTER',
#        'OTHER SPECIFIED AND UNSPECIFIED NUTRITIONAL AND METABOLIC DISORDERS',
#        'DISORDERS OF TEETH AND GINGIVA', 'HALLUCINOGEN-RELATED DISORDERS',
#        'ENDOMETRIOSIS', 'APLASTIC ANEMIA',
#        'ENDOCRINE SYSTEM CANCERS - PANCREAS',
#        'GASTROINTESTINAL CANCERS - ALL OTHER TYPES',
#        'PROLAPSE OF FEMALE GENITAL ORGANS',
#        'PLEURISY, PLEURAL EFFUSION AND PULMONARY COLLAPSE',
#        'EFFECT OF OTHER EXTERNAL CAUSES, INITIAL ENCOUNTER',
#        'BURN AND CORROSION, INITIAL ENCOUNTER',
#        'INJURY TO BLOOD VESSELS, INITIAL ENCOUNTER',
#        'FRACTURE OF THE SPINE AND BACK, INITIAL ENCOUNTER',
#        'POSTPROCEDURAL OR POSTOPERATIVE ENDOCRINE OR METABOLIC COMPLICATION',
#        'COMPLICATION OF CARDIOVASCULAR DEVICE, IMPLANT OR GRAFT, INITIAL ENCOUNTER',
#        'MYOCARDITIS AND CARDIOMYOPATHY',
#        'FEMALE REPRODUCTIVE SYSTEM CANCERS - CERVIX',
#        'MALTREATMENT/ABUSE',
#        'POSTPROCEDURAL OR POSTOPERATIVE CIRCULATORY SYSTEM COMPLICATION',
#        'NUTRITIONAL ANEMIA',
#        'OTHER SPECIFIED AND UNSPECIFIED ENDOCRINE DISORDERS',
#        'GASTROINTESTINAL CANCERS - LIVER',
#        'MISCELLANEOUS MENTAL AND BEHAVIORAL DISORDERS/CONDITIONS'],
#       dtype=object)

# %% [markdown]
# ### NOTES:
# My model can only take in data that will be available at the relevant time of the prediction (eg. I can't try to predict stock price of yesterday knowing today's stock price). This brings up some questions for the context of predicting length of stay:
# 1. Would this prediction happen before the woman goes to the hospital? In this case the only predictive input data to go on would be where they live, the hospital they are going to (planning to), their age group, gender, race, and maybe an idea of the procedure to be done (but no official diagnosis which is what I have in the dataset nor knowledge of the complications to arise). This is tricky.
# 2. Would this prediction happen once the woman is in the hospital and presumably has given birth; are we estimating recovery time in hospital for a known procedure? This would allow me to use all of the data I have (yay) but I'm not sure if it would be as helpful in context. (Would a soon-to-be-again mother prepare guarenteed childcare for the kids for 2 days but wonder once given birth how much longer should be arranged, or is that superfulous information at that point?)

# %%
# for col in results_df.columns:
#     print(col)
#     print('\t', results_df[col].unique())

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("health.data.ny.gov", None)
soql_query = "SELECT * WHERE ccsr_diagnosis_code LIKE '%INJ%' LIMIT 10000000"
injuries = client.get("tg3i-cinn", query=soql_query)

injuries_df = pd.DataFrame.from_records(injuries)
injuries_df
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#        hospital_service_area hospital_county operating_certificate_number  \
# 0              New York City           Bronx                      7000006
# 1              New York City           Bronx                      7000006
# 2              New York City           Bronx                      7000006
# 3              New York City           Bronx                      7000006
# 4              New York City       Manhattan                      7002001
# ...                      ...             ...                          ...
# 154431         New York City           Bronx                      7000002
# 154432         New York City           Bronx                      7000002
# 154433         New York City          Queens                      7003000
# 154434         New York City           Bronx                      7000002
# 154435         Hudson Valley     Westchester                      5902002
#
#        permanent_facility_id  \
# 0                     003058
# 1                     001169
# 2                     001169
# 3                     001169
# 4                     001438
# ...                      ...
# 154431                001165
# 154432                001165
# 154433                001626
# 154434                001165
# 154435                001046
#
#                                             facility_name    age_group  \
# 0       Montefiore Med Center - Jack D Weiler Hosp of ...     50 to 69
# 1       Montefiore Medical Center - Henry & Lucy Moses...     50 to 69
# 2       Montefiore Medical Center - Henry & Lucy Moses...     50 to 69
# 3       Montefiore Medical Center - Henry & Lucy Moses...     30 to 49
# 4                                Bellevue Hospital Center     50 to 69
# ...                                                   ...          ...
# 154431                              Jacobi Medical Center     18 to 29
# 154432                              Jacobi Medical Center  70 or Older
# 154433                           Elmhurst Hospital Center  70 or Older
# 154434                              Jacobi Medical Center      0 to 17
# 154435   Winifred Masterson Burke Rehabilitation Hospital  70 or Older
#
#        zip_code_3_digits gender                    race          ethnicity  \
# 0                    105      M              Other Race   Spanish/Hispanic
# 1                    104      F  Black/African American  Not Span/Hispanic
# 2                    104      M              Other Race   Spanish/Hispanic
# 3                    104      M              Other Race            Unknown
# 4                    114      F  Black/African American            Unknown
# ...                  ...    ...                     ...                ...
# 154431               104      M              Other Race            Unknown
# 154432               100      M  Black/African American  Not Span/Hispanic
# 154433               113      F              Other Race   Spanish/Hispanic
# 154434               104      F  Black/African American  Not Span/Hispanic
# 154435               105      F                   White            Unknown
#
#         ... apr_severity_of_illness apr_risk_of_mortality  \
# 0       ...                   Major              Moderate
# 1       ...                   Minor                 Minor
# 2       ...                Moderate              Moderate
# 3       ...                 Extreme                 Major
# 4       ...                   Major                 Minor
# ...     ...                     ...                   ...
# 154431  ...                Moderate                 Minor
# 154432  ...                 Extreme               Extreme
# 154433  ...                Moderate              Moderate
# 154434  ...                Moderate                 Minor
# 154435  ...                   Major                 Major
#
#        apr_medical_surgical        payment_typology_1  \
# 0                   Medical  Private Health Insurance
# 1                   Medical                  Medicare
# 2                   Medical                  Medicare
# 3                   Medical  Private Health Insurance
# 4                   Medical                  Medicaid
# ...                     ...                       ...
# 154431             Surgical                  Self-Pay
# 154432             Surgical       Miscellaneous/Other
# 154433             Surgical                  Medicare
# 154434              Medical       Miscellaneous/Other
# 154435              Medical                  Medicare
#
#        emergency_department_indicator total_charges total_costs  \
# 0                                   Y     109269.27    18443.00
# 1                                   Y      24437.19     3060.38
# 2                                   Y     270656.16    48268.17
# 3                                   N      88167.44    15579.66
# 4                                   Y      41548.87    23894.09
# ...                               ...           ...         ...
# 154431                              Y     179936.46   106799.13
# 154432                              Y     289988.58   172119.24
# 154433                              Y     119307.70    55453.74
# 154434                              Y       6324.49     3753.83
# 154435                              N      87880.91    43103.93
#
#        payment_typology_2 payment_typology_3 birth_weight
# 0                     NaN                NaN          NaN
# 1                Medicaid                NaN          NaN
# 2                Medicaid                NaN          NaN
# 3                     NaN                NaN          NaN
# 4                     NaN                NaN          NaN
# ...                   ...                ...          ...
# 154431                NaN                NaN          NaN
# 154432           Medicare                NaN          NaN
# 154433           Medicaid                NaN          NaN
# 154434           Medicaid                NaN          NaN
# 154435                NaN                NaN          NaN
#
# [154436 rows x 33 columns]

# %%
injuries_df['ccsr_diagnosis_description'].unique()
# Out:
# array(['COMPLICATION OF OTHER SURGICAL OR MEDICAL CARE, INJURY, INITIAL ENCOUNTER',
#        'TRAUMATIC BRAIN INJURY (TBI); CONCUSSION, INITIAL ENCOUNTER',
#        'COMPLICATION OF TRANSPLANTED ORGANS OR TISSUE, INITIAL ENCOUNTER',
#        'FRACTURE OF TORSO, INITIAL ENCOUNTER',
#        'DISLOCATIONS, INITIAL ENCOUNTER',
#        'POISONING BY DRUGS, INITIAL ENCOUNTER',
#        'OPEN WOUNDS OF HEAD AND NECK, INITIAL ENCOUNTER',
#        'FRACTURE OF THE UPPER LIMB, INITIAL ENCOUNTER',
#        'OPEN WOUNDS TO LIMBS, INITIAL ENCOUNTER', 'ALLERGIC REACTIONS',
#        'AMPUTATION OF A LIMB, INITIAL ENCOUNTER',
#        'INTERNAL ORGAN INJURY, INITIAL ENCOUNTER',
#        'FRACTURE OF THE NECK OF THE FEMUR (HIP), INITIAL ENCOUNTER',
#        'FRACTURE OF THE LOWER LIMB (EXCEPT HIP), INITIAL ENCOUNTER',
#        'TRAUMATIC BRAIN INJURY (TBI); CONCUSSION, SUBSEQUENT ENCOUNTER',
#        'COMPLICATION OF INTERNAL ORTHOPEDIC DEVICE OR IMPLANT, INITIAL ENCOUNTER',
#        'COMPLICATION OF GENITOURINARY DEVICE, IMPLANT OR GRAFT, INITIAL ENCOUNTER',
#        'DRUG INDUCED OR TOXIC RELATED CONDITION',
#        'TOXIC EFFECTS, INITIAL ENCOUNTER',
#        'EFFECT OF FOREIGN BODY ENTERING OPENING, INITIAL ENCOUNTER',
#        'FRACTURE OF HEAD AND NECK, INITIAL ENCOUNTER',
#        'SUPERFICIAL INJURY; CONTUSION, INITIAL ENCOUNTER',
#        'OTHER UNSPECIFIED INJURY', 'INJURY, SEQUELA',
#        'OPEN WOUNDS OF TRUNK, INITIAL ENCOUNTER',
#        'FRACTURE OF LOWER LIMB (EXCEPT HIP), SUBSEQUENT ENCOUNTER',
#        'FRACTURE OF TORSO, SUBSEQUENT ENCOUNTER',
#        'EFFECT OF OTHER EXTERNAL CAUSES, INITIAL ENCOUNTER',
#        'BURN AND CORROSION, INITIAL ENCOUNTER',
#        'INJURY TO BLOOD VESSELS, INITIAL ENCOUNTER',
#        'FRACTURE OF THE SPINE AND BACK, INITIAL ENCOUNTER',
#        'COMPLICATION OF CARDIOVASCULAR DEVICE, IMPLANT OR GRAFT, INITIAL ENCOUNTER',
#        'MALTREATMENT/ABUSE',
#        'INTERNAL ORGAN INJURY, SUBSEQUENT ENCOUNTER',
#        'FRACTURE OF THE NECK OF THE FEMUR (HIP), SUBSEQUENT ENCOUNTER',
#        'FRACTURE OF THE SPINE AND BACK, SUBSEQUENT ENCOUNTER',
#        'SPRAINS AND STRAINS, INITIAL ENCOUNTER',
#        'TOXIC EFFECTS, SUBSEQUENT ENCOUNTER',
#        'INJURY TO NERVES, MUSCLES AND TENDONS, INITIAL ENCOUNTER',
#        'BURNS AND CORROSION, SUBSEQUENT ENCOUNTER',
#        'SPINAL CORD INJURY (SCI), INITIAL ENCOUNTER',
#        'FRACTURE OF HEAD AND NECK, SUBSEQUENT ENCOUNTER',
#        'CRUSHING INJURY, INITIAL ENCOUNTER', 'OTHER SPECIFIED INJURY',
#        'FRACTURE OF THE UPPER LIMB, SUBSEQUENT ENCOUNTER',
#        'SPINAL CORD INJURY (SCI), SUBSEQUENT ENCOUNTER',
#        'INJURY TO NERVES, MUSCLES AND TENDONS, SUBSEQUENT ENCOUNTER',
#        'CRUSHING INJURY, SUBSEQUENT ENCOUNTER',
#        'OPEN WOUNDS TO LIMBS, SUBSEQUENT ENCOUNTER',
#        'COMPLICATION, SEQUELA',
#        'SUPERFICIAL INJURY; CONTUSION, SUBSEQUENT ENCOUNTER',
#        'COMPLICATION OF OTHER SURGICAL OR MEDICAL CARE, INJURY, SUBSEQUENT ENCOUNTER',
#        'COMPLICATION OF INTERNAL ORTHOPEDIC DEVICE OR IMPLANT, SUBSEQUENT ENCOUNTER',
#        'EFFECT OF OTHER EXTERNAL CAUSES, SUBSEQUENT ENCOUNTER',
#        'OTHER SPECIFIED INJURY, SUBSEQUENT ENCOUNTER',
#        'COMPLICATION OF CARDIOVASCULAR DEVICE, IMPLANT OR GRAFT, SUBSEQUENT ENCOUNTER',
#        'ALLERGIC REACTIONS, SUBSEQUENT ENCOUNTER',
#        'COMPLICATION OF GENITOURINARY DEVICE, IMPLANT OR GRAFT, SUBSEQUENT ENCOUNTER',
#        'ADVERSE EFFECTS OF DRUGS AND MEDICAMENTS, INITIAL ENCOUNTER',
#        'AMPUTATION OF OTHER BODY PARTS, INITIAL ENCOUNTER',
#        'SPRAINS AND STRAINS, SUBSEQUENT ENCOUNTER',
#        'POISONING/TOXIC EFFECT/ADVERSE EFFECTS/UNDERDOSING, SEQUELA',
#        'POISONING BY DRUGS, SUBSEQUENT ENCOUNTER',
#        'AMPUTATION OF A LIMB, SUBSEQUENT ENCOUNTER',
#        'DISLOCATIONS, SUBSEQUENT ENCOUNTER',
#        'OPEN WOUNDS OF HEAD AND NECK, SUBSEQUENT ENCOUNTER',
#        'OPEN WOUNDS OF TRUNK, SUBSEQUENT ENCOUNTER',
#        'MALTREATMENT/ABUSE, SUBSEQUENT ENCOUNTER',
#        'EFFECT OF FOREIGN BODY ENTERING OPENING, SUBSEQUENT ENCOUNTER',
#        'INJURY TO BLOOD VESSELS, SUBSEQUENT ENCOUNTER',
#        'OTHER UNSPECIFIED INJURIES, SUBSEQUENT ENCOUNTER'], dtype=object)

# %% [markdown]
# ## All pregnancy-related visits

# %%
import pandas as pd
from sodapy import Socrata

client = Socrata("health.data.ny.gov", None)
soql_query = "SELECT * WHERE ccsr_diagnosis_code LIKE '%PRG%' LIMIT 10000000"
prg_results = client.get("tg3i-cinn", query=soql_query)

pregnancy_visits = pd.DataFrame.from_records(prg_results)
pregnancy_visits
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#        hospital_service_area hospital_county operating_certificate_number  \
# 0              New York City           Bronx                      7000006
# 1              New York City           Kings                      7001009
# 2              New York City       Manhattan                      7002001
# 3              New York City       Manhattan                      7002001
# 4              New York City           Kings                      7001045
# ...                      ...             ...                          ...
# 221015           Long Island          Nassau                      7003004
# 221016           Long Island          Nassau                      7003004
# 221017           Long Island          Nassau                      7003004
# 221018         New York City          Queens                      7003007
# 221019          Finger Lakes         Steuben                      5001000
#
#        permanent_facility_id                                 facility_name  \
# 0                     001168  Montefiore Medical Center-Wakefield Hospital
# 1                     001294                         Coney Island Hospital
# 2                     001438                      Bellevue Hospital Center
# 3                     001438                      Bellevue Hospital Center
# 4                     001692       Woodhull Medical & Mental Health Center
# ...                      ...                                           ...
# 221015                001630             Long Island Jewish Medical Center
# 221016                001630             Long Island Jewish Medical Center
# 221017                001630             Long Island Jewish Medical Center
# 221018                001633                        Queens Hospital Center
# 221019                000866                              Corning Hospital
#
#        age_group zip_code_3_digits gender                    race  \
# 0       18 to 29               104      F              Other Race
# 1       30 to 49               112      F              Other Race
# 2       30 to 49               100      F  Black/African American
# 3       30 to 49               113      F              Other Race
# 4       18 to 29               112      F                   White
# ...          ...               ...    ...                     ...
# 221015  18 to 29               117      F                   White
# 221016  30 to 49               110      F              Other Race
# 221017  18 to 29               112      F                   White
# 221018  18 to 29               114      F  Black/African American
# 221019  18 to 29               OOS      F                   White
#
#                 ethnicity  ... apr_severity_of_illness apr_risk_of_mortality  \
# 0        Spanish/Hispanic  ...                   Minor                 Minor
# 1        Spanish/Hispanic  ...                Moderate                 Minor
# 2       Not Span/Hispanic  ...                   Minor                 Minor
# 3        Spanish/Hispanic  ...                   Minor                 Minor
# 4                 Unknown  ...                Moderate                 Minor
# ...                   ...  ...                     ...                   ...
# 221015  Not Span/Hispanic  ...                   Minor                 Minor
# 221016  Not Span/Hispanic  ...                Moderate                 Minor
# 221017  Not Span/Hispanic  ...                   Minor                 Minor
# 221018            Unknown  ...                Moderate                 Minor
# 221019  Not Span/Hispanic  ...                   Minor                 Minor
#
#        apr_medical_surgical        payment_typology_1  \
# 0                  Surgical                  Medicaid
# 1                  Surgical                  Medicaid
# 2                   Medical                  Medicaid
# 3                  Surgical                  Medicaid
# 4                   Medical                  Medicaid
# ...                     ...                       ...
# 221015              Medical    Blue Cross/Blue Shield
# 221016              Medical    Blue Cross/Blue Shield
# 221017              Medical  Private Health Insurance
# 221018              Medical                  Medicaid
# 221019              Medical  Private Health Insurance
#
#        emergency_department_indicator total_charges total_costs  \
# 0                                   N      42705.34    11366.50
# 1                                   N      34775.79    15891.81
# 2                                   N      24475.78    14075.63
# 3                                   N      31914.35    18353.43
# 4                                   N      23311.38    15888.78
# ...                               ...           ...         ...
# 221015                              N      42902.01     8440.02
# 221016                              N      16526.90     5337.24
# 221017                              N      19741.34     7198.87
# 221018                              Y      49696.50    22213.54
# 221019                              N       6296.75     4197.53
#
#        payment_typology_2 payment_typology_3 birth_weight
# 0                     NaN                NaN          NaN
# 1                     NaN                NaN          NaN
# 2                     NaN                NaN          NaN
# 3                     NaN                NaN          NaN
# 4                     NaN                NaN          NaN
# ...                   ...                ...          ...
# 221015           Self-Pay                NaN          NaN
# 221016           Medicaid           Medicaid          NaN
# 221017           Medicaid           Self-Pay          NaN
# 221018                NaN                NaN          NaN
# 221019                NaN                NaN          NaN
#
# [221020 rows x 33 columns]

# %% [markdown]
# ##### The following are the DIAGNOSIS codes in the pregnancy-related data

# %%
print(pregnancy_visits['ccsr_diagnosis_code'].unique())
print(pregnancy_visits['ccsr_diagnosis_description'].unique())

# notes: 201k data points is too many, need to cut down
# I'm not sure that I want to consider separate post-op visits like previous c section complications, but if I was predicting time in the hospital maybe?
# Out:
# ['PRG016' 'PRG020' 'PRG023' 'PRG024' 'PRG019' 'PRG013' 'PRG006' 'PRG018'
#  'PRG022' 'PRG005' 'PRG009' 'PRG014' 'PRG011' 'PRG029' 'PRG012' 'PRG003'
#  'PRG028' 'PRG027' 'PRG026' 'PRG017' 'PRG004' 'PRG021' 'PRG015' 'PRG010'
#  'PRG025' 'PRG007' 'PRG001']
# ['PREVIOUS C-SECTION'
#  'HYPERTENSION AND HYPERTENSIVE-RELATED CONDITIONS COMPLICATING PREGNANCY; CHILDBIRTH; AND THE PUERPERIUM'
#  'COMPLICATIONS SPECIFIED DURING CHILDBIRTH'
#  'MALPOSITION, DISPROPORTION OR OTHER LABOR COMPLICATIONS'
#  'DIABETES OR ABNORMAL GLUCOSE TOLERANCE COMPLICATING PREGNANCY; CHILDBIRTH; OR THE PUERPERIUM'
#  'MATERNAL CARE RELATED TO FETAL CONDITIONS'
#  'MOLAR PREGNANCY AND OTHER ABNORMAL PRODUCTS OF CONCEPTION'
#  'MATERNAL CARE RELATED TO DISORDERS OF THE PLACENTA AND PLACENTAL IMPLANTATION'
#  'PROLONGED PREGNANCY'
#  'ECTOPIC PREGNANCY AND COMPLICATIONS OF ECTOPIC PREGNANCY'
#  'EARLY, FIRST OR UNSPECIFIED TRIMESTER HEMORRHAGE'
#  'POLYHYDRAMNIOS AND OTHER PROBLEMS OF AMNIOTIC CAVITY'
#  'EARLY OR THREATENED LABOR'
#  'UNCOMPLICATED PREGNANCY, DELIVERY OR PUERPERIUM' 'MULTIPLE GESTATION'
#  'SPONTANEOUS ABORTION AND COMPLICATIONS OF SPONTANEOUS ABORTION'
#  'OTHER SPECIFIED COMPLICATIONS IN PREGNANCY'
#  'COMPLICATIONS SPECIFIED DURING THE PUERPERIUM'
#  'OB-RELATED TRAUMA TO PERINEUM AND VULVA'
#  'MATERNAL CARE FOR ABNORMALITY OF PELVIC ORGANS'
#  'INDUCED ABORTION AND COMPLICATIONS OF TERMINATION OF PREGNANCY'
#  'MATERNAL INTRAUTERINE INFECTION'
#  'OBSTETRIC HISTORY AFFECTING CARE IN PREGNANCY'
#  'HEMORRHAGE AFTER FIRST TRIMESTER'
#  'ANESTHESIA COMPLICATIONS DURING PREGNANCY'
#  'COMPLICATIONS FOLLOWING ECTOPIC AND/OR MOLAR PREGNANCY'
#  'ANTENATAL SCREENING']

# %%
print('Lengths of stay for ALL pregnancy-related visits:')
lens = list(pregnancy_visits['length_of_stay'].unique())
lens.remove('120 +')
lengths_of_stay = [int(i) for i in lens]
print(lengths_of_stay)
print('MIN:', min(lengths_of_stay))
print('MAX:', max(lengths_of_stay))
print('MEDIAN:', np.median(lengths_of_stay))
print('MEAN:', np.mean(lengths_of_stay))
# Out:
# Lengths of stay for ALL pregnancy-related visits:
# [2, 3, 1, 6, 5, 4, 31, 23, 9, 43, 10, 7, 11, 12, 14, 29, 8, 15, 18, 20, 27, 19, 13, 21, 30, 37, 16, 28, 51, 17, 26, 33, 24, 42, 38, 55, 22, 44, 45, 75, 32, 25, 50, 87, 35, 65, 36, 56, 52, 39, 34, 73, 48, 96, 59, 40, 46, 112, 57, 61, 53, 76, 66, 103, 67, 41, 49, 69, 64, 78, 70, 86, 92, 62, 47, 80, 63, 54, 85, 119, 58, 93, 68, 81, 74]
# MIN: 1
# MAX: 119
# MEDIAN: 43.0
# MEAN: 45.11764705882353

# %% [markdown]
# ## Uncomplicated pregancy, delivery of puerperium
# ##### So far, this is the only column that I see to be strictly delivery related. If you see other columns that look related I would be happy to add them to the following.

# %%
uncomplicated_births = pregnancy_visits.loc[pregnancy_visits['ccsr_diagnosis_description'] == 'UNCOMPLICATED PREGNANCY, DELIVERY OR PUERPERIUM']
uncomplicated_births
# Out:
#        hospital_service_area hospital_county operating_certificate_number  \
# 42             New York City       Manhattan                      7002024
# 54             New York City          Queens                      7003000
# 61             New York City           Bronx                      7000008
# 67             New York City           Kings                      7001009
# 78             New York City       Manhattan                      7002009
# ...                      ...             ...                          ...
# 220985         New York City           Kings                      7001020
# 220993         New York City           Bronx                      7000002
# 220994         New York City       Manhattan                      7002024
# 221004         New York City       Manhattan                      7002021
# 221017           Long Island          Nassau                      7003004
#
#        permanent_facility_id                           facility_name  \
# 42                    001456                    Mount Sinai Hospital
# 54                    001626                Elmhurst Hospital Center
# 61                    001172  Lincoln Medical & Mental Health Center
# 67                    001294                   Coney Island Hospital
# 78                    001445                  Harlem Hospital Center
# ...                      ...                                     ...
# 220985                001305               Maimonides Medical Center
# 220993                001186            North Central Bronx Hospital
# 220994                001456                    Mount Sinai Hospital
# 221004                001454            Metropolitan Hospital Center
# 221017                001630       Long Island Jewish Medical Center
#
#        age_group zip_code_3_digits gender                    race  \
# 42      30 to 49               100      F              Other Race
# 54      30 to 49               113      F              Other Race
# 61      18 to 29               100      F              Other Race
# 67      30 to 49               112      F              Other Race
# 78      18 to 29               100      F  Black/African American
# ...          ...               ...    ...                     ...
# 220985  30 to 49               112      F                   White
# 220993  30 to 49               104      F              Other Race
# 220994  30 to 49               100      F                   White
# 221004  30 to 49               100      F              Other Race
# 221017  18 to 29               112      F                   White
#
#                 ethnicity  ... apr_severity_of_illness apr_risk_of_mortality  \
# 42      Not Span/Hispanic  ...                Moderate                 Minor
# 54       Spanish/Hispanic  ...                Moderate                 Minor
# 61       Spanish/Hispanic  ...                   Minor                 Minor
# 67       Spanish/Hispanic  ...                Moderate              Moderate
# 78      Not Span/Hispanic  ...                   Minor                 Minor
# ...                   ...  ...                     ...                   ...
# 220985  Not Span/Hispanic  ...                   Minor                 Minor
# 220993   Spanish/Hispanic  ...                   Minor                 Minor
# 220994  Not Span/Hispanic  ...                Moderate                 Minor
# 221004   Spanish/Hispanic  ...                   Minor                 Minor
# 221017  Not Span/Hispanic  ...                   Minor                 Minor
#
#        apr_medical_surgical        payment_typology_1  \
# 42                 Surgical  Private Health Insurance
# 54                  Medical                  Medicaid
# 61                  Medical                  Medicaid
# 67                  Medical                  Medicaid
# 78                  Medical                  Medicaid
# ...                     ...                       ...
# 220985             Surgical  Private Health Insurance
# 220993              Medical                  Medicaid
# 220994             Surgical  Private Health Insurance
# 221004              Medical                  Medicaid
# 221017              Medical  Private Health Insurance
#
#        emergency_department_indicator total_charges total_costs  \
# 42                                  N      43658.10    15155.30
# 54                                  N      25611.60    11904.17
# 61                                  N      22641.71    14470.88
# 67                                  N      23060.37    10538.10
# 78                                  N      44202.07    33912.80
# ...                               ...           ...         ...
# 220985                              Y      43112.04    11321.96
# 220993                              N      15972.32     9480.18
# 220994                              N      47626.98    15963.48
# 221004                              N      30544.21    27551.34
# 221017                              N      19741.34     7198.87
#
#        payment_typology_2 payment_typology_3 birth_weight
# 42               Self-Pay                NaN          NaN
# 54                    NaN                NaN          NaN
# 61                    NaN                NaN          NaN
# 67                    NaN                NaN          NaN
# 78                    NaN                NaN          NaN
# ...                   ...                ...          ...
# 220985           Medicaid           Self-Pay          NaN
# 220993                NaN                NaN          NaN
# 220994           Self-Pay                NaN          NaN
# 221004                NaN                NaN          NaN
# 221017           Medicaid           Self-Pay          NaN
#
# [18804 rows x 33 columns]

# %%
print(uncomplicated_births['ccsr_procedure_description'].unique())
# Out:
# ['SPONTANEOUS VAGINAL DELIVERY' 'FETAL HEART RATE MONITORING'
#  'PERINEAL MUSCLE LACERATION REPAIR (2ND DEGREE OBSTETRICAL AND OTHER)'
#  'CESAREAN SECTION' 'ASSISTED VAGINAL DELIVERY'
#  'PERINEAL SKIN REPAIR (1ST DEGREE OBSTETRICAL AND OTHER)' 'EPISIOTOMY'
#  'CERVICAL RIPENING' 'INTRAUTERINE DEVICE (IUD) INSERTION'
#  'INTRAVENOUS INDUCTION OF LABOR'
#  'FEMALE GENITAL TRACT REPAIR (EXCLUDING VULVA)'
#  'ADMINISTRATION OF THERAPEUTIC SUBSTANCES, NEC'
#  'VULVAR LACERATION REPAIR' nan
#  'ANORECTAL REPAIR (3RD AND 4TH DEGREE OBSTETRICAL REPAIRS AND OTHER)'
#  'PREGNANCY AND FETAL PROCEDURES, NEC' 'SALPINGECTOMY'
#  'TRANSFUSION OF BLOOD AND BLOOD PRODUCTS'
#  'ENDOSCOPIC CONTROL OF BLEEDING'
#  'REMOVAL OF PLACENTA AND OTHER RETAINED PRODUCTS OF CONCEPTION'
#  'REGIONAL ANESTHESIA' 'PHERESIS THERAPY'
#  'FALLOPIAN TUBE LIGATION AND EXCISION'
#  'SUBCUTANEOUS CONTRACEPTIVE IMPLANT'
#  'FEMALE LOWER GENITAL TRACT EXCISION'
#  'CONTROL OF BLEEDING (NON-ENDOSCOPIC)' 'VACCINATIONS'
#  'FEMALE REPRODUCTIVE SYSTEM PROCEDURES, NEC' 'CERVICAL DILATION'
#  'SPINAL EPIDURAL CATHETER PLACEMENT'
#  'CYSTOSCOPY AND URETEROSCOPY (INCLUDING BIOPSY)' 'ISOLATION PROCEDURES'
#  'ADMINISTRATION OF ANTIBIOTICS'
#  'SUBCUTANEOUS TISSUE AND FASCIA PROCEDURES, NEC'
#  'ADMINISTRATION OF NUTRITIONAL AND ELECTROLYTIC SUBSTANCES'
#  'HYSTERECTOMY']

# %%
print('Lengths of stay for uncomplicated-birth-related visits:')
lens = list(uncomplicated_births['length_of_stay'].unique())
lengths_of_stay = [int(i) for i in lens]
print(lengths_of_stay)
print('MIN:', min(lengths_of_stay))
print('MAX:', max(lengths_of_stay))
print('MEDIAN:', np.median(lengths_of_stay))
print('MEAN:', np.mean(lengths_of_stay))
# Out:
# Lengths of stay for uncomplicated-birth-related visits:
# [3, 2, 1, 4, 5, 6, 14, 11, 7, 10, 8, 9, 12, 17, 13]
# MIN: 1
# MAX: 17
# MEDIAN: 8.0
# MEAN: 8.133333333333333

# %%
uncomplicated_births.columns
# Out:
# Index(['hospital_service_area', 'hospital_county',
#        'operating_certificate_number', 'permanent_facility_id',
#        'facility_name', 'age_group', 'zip_code_3_digits', 'gender', 'race',
#        'ethnicity', 'length_of_stay', 'type_of_admission',
#        'patient_disposition', 'discharge_year', 'ccsr_diagnosis_code',
#        'ccsr_diagnosis_description', 'ccsr_procedure_code',
#        'ccsr_procedure_description', 'apr_drg_code', 'apr_drg_description',
#        'apr_mdc_code', 'apr_mdc_description', 'apr_severity_of_illness_code',
#        'apr_severity_of_illness', 'apr_risk_of_mortality',
#        'apr_medical_surgical', 'payment_typology_1',
#        'emergency_department_indicator', 'total_charges', 'total_costs',
#        'payment_typology_2', 'payment_typology_3', 'birth_weight'],
#       dtype='object')

# %%
uncomplicated_births['apr_risk_of_mortality'].value_counts()
# Out:
# apr_risk_of_mortality
# Minor       18239
# Moderate      495
# Major          42
# Extreme        10
# Name: count, dtype: int64

# %%
planned_delivery = uncomplicated_births.loc[:, ['hospital_service_area', 'hospital_county',
       'operating_certificate_number', 'permanent_facility_id',
       'facility_name', 'age_group', 'zip_code_3_digits', 'gender', 'race',
       'ethnicity', 'payment_typology_1','payment_typology_2', 'payment_typology_3', 'length_of_stay']]
#planned_delivery = planned_delivery.reset_index()

# %%
planned_delivery
# Out:
#        hospital_service_area hospital_county operating_certificate_number  \
# 42             New York City       Manhattan                      7002024
# 54             New York City          Queens                      7003000
# 61             New York City           Bronx                      7000008
# 67             New York City           Kings                      7001009
# 78             New York City       Manhattan                      7002009
# ...                      ...             ...                          ...
# 220985         New York City           Kings                      7001020
# 220993         New York City           Bronx                      7000002
# 220994         New York City       Manhattan                      7002024
# 221004         New York City       Manhattan                      7002021
# 221017           Long Island          Nassau                      7003004
#
#        permanent_facility_id                           facility_name  \
# 42                    001456                    Mount Sinai Hospital
# 54                    001626                Elmhurst Hospital Center
# 61                    001172  Lincoln Medical & Mental Health Center
# 67                    001294                   Coney Island Hospital
# 78                    001445                  Harlem Hospital Center
# ...                      ...                                     ...
# 220985                001305               Maimonides Medical Center
# 220993                001186            North Central Bronx Hospital
# 220994                001456                    Mount Sinai Hospital
# 221004                001454            Metropolitan Hospital Center
# 221017                001630       Long Island Jewish Medical Center
#
#        age_group zip_code_3_digits gender                    race  \
# 42      30 to 49               100      F              Other Race
# 54      30 to 49               113      F              Other Race
# 61      18 to 29               100      F              Other Race
# 67      30 to 49               112      F              Other Race
# 78      18 to 29               100      F  Black/African American
# ...          ...               ...    ...                     ...
# 220985  30 to 49               112      F                   White
# 220993  30 to 49               104      F              Other Race
# 220994  30 to 49               100      F                   White
# 221004  30 to 49               100      F              Other Race
# 221017  18 to 29               112      F                   White
#
#                 ethnicity        payment_typology_1 payment_typology_2  \
# 42      Not Span/Hispanic  Private Health Insurance           Self-Pay
# 54       Spanish/Hispanic                  Medicaid                NaN
# 61       Spanish/Hispanic                  Medicaid                NaN
# 67       Spanish/Hispanic                  Medicaid                NaN
# 78      Not Span/Hispanic                  Medicaid                NaN
# ...                   ...                       ...                ...
# 220985  Not Span/Hispanic  Private Health Insurance           Medicaid
# 220993   Spanish/Hispanic                  Medicaid                NaN
# 220994  Not Span/Hispanic  Private Health Insurance           Self-Pay
# 221004   Spanish/Hispanic                  Medicaid                NaN
# 221017  Not Span/Hispanic  Private Health Insurance           Medicaid
#
#        payment_typology_3 length_of_stay
# 42                    NaN              3
# 54                    NaN              3
# 61                    NaN              2
# 67                    NaN              2
# 78                    NaN              3
# ...                   ...            ...
# 220985           Self-Pay              3
# 220993                NaN              1
# 220994                NaN              3
# 221004                NaN              2
# 221017           Self-Pay              1
#
# [18804 rows x 14 columns]

# %%
planned_delivery['length_of_stay'].unique()
# Out:
# array(['3', '2', '1', '4', '5', '6', '14', '11', '7', '10', '8', '9',
#        '12', '17', '13'], dtype=object)

# %%
planned_delivery.dtypes
# Out:
# hospital_service_area           object
# hospital_county                 object
# operating_certificate_number    object
# permanent_facility_id           object
# facility_name                   object
# age_group                       object
# zip_code_3_digits               object
# gender                          object
# race                            object
# ethnicity                       object
# payment_typology_1              object
# payment_typology_2              object
# payment_typology_3              object
# length_of_stay                  object
# dtype: object

# %%
planned_delivery['operating_certificate_number'].unique()
# Out:
# array(['7002024', '7003000', '7000008', '7001009', '7002009', '7001016',
#        '7000006', '7002053', '7001021', '2908000', '7003010', '5901000',
#        nan, '7002021', '3824000', '7002032', '7002001', '7000024',
#        '2950002', '7001037', '4324000', '7000002', '7001045', '7003007',
#        '3429000', '2701005', '2701001', '5904001', '7001003', '7000001',
#        '0101000', '3301008', '3523000', '5263000', '5601000', '1101000',
#        '5001000', '0228000', '7001020', '4601001', '5932000', '3202003',
#        '0301001', '5155000', '5154000', '2950001', '7003004', '0101004',
#        '7002017', '2601001', '2951001', '7004003', '0602001', '3702000',
#        '3950000', '2201000', '1327000', '2527000', '5922000', '5153000',
#        '7004010', '5957001', '1624000', '5151001', '3301007', '5401001',
#        '4429000', '2238700', '5501001', '7001024', '2801001', '7003001',
#        '0601000', '0401001', '7003003', '3102000', '7001035', '4501000',
#        '3522000', '6027000', '0701000', '3201002', '7001002', '5902001',
#        '4401000', '5154001', '1401008', '1401013', '0824000', '4329000',
#        '0303001', '1302001', '3301003', '0501000', '5820000', '1801000',
#        '2754001', '7000014', '5907001', '2701003', '1701000', '7002054',
#        '4102002', '5149001', '2909000', '5157003', '1623001', '1401014',
#        '3529000', '5920000', '3121001', '0901001'], dtype=object)

# %% [markdown]
# ## Export data to csv files for later

# %%
#pregnancy_visits.to_csv('./data/pregnancy_related_visits.csv')

# %%
#uncomplicated_births.to_csv('./data/uncomplicated_delivery_visits.csv')

# %%
#planned_delivery.to_csv('./data/planned_deliveries.csv')
